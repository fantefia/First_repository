# %% [markdown]
# <a href="https://colab.research.google.com/github/fantefia/First_repository/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def pangram(text):
    alphabet = set('abcdefghijklmnopqrstuvwxyz')
    text_set = set(text.lower())
    return alphabet.issubset(text_set)
